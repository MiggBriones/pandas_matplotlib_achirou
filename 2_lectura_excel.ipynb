# %%
import pandas as pd

# %%
pd.read_excel?

# %% [markdown]
# ### Instalar libreria openpyxl

# %% [markdown]
# Se necesita instalar la libreria openpyxl para poder trabajar con ficheros excel
#
# `pip install openpyxl`

# %% [markdown]
# **Nota:** Puedo acceder a la pestaña que necesite, colocando el nombre y accedo al dataframe

# %% [markdown]
# ![2_lectura_excel_pestania.png](recursos/2_lectura_excel_pestania.png)

# %%
df_read = pd.read_excel('recursos/album.xlsx', 'title')
df_read
# Out:
#                                title                artist            upc
# 0                            Letters          Chris Daniel  7316211652314
# 1              Three Dimensions Deep            Amber Mark   602508362125
# 2                         Born Again  The Notorious B.I.G.   786127302363
# 3                             HNDRXX                Future   886446604039
# 4                  All Rise (Deluxe)        Gregory Porter   602508620119
# 5                        After Hours            The Weeknd   602508924224
# 6                Creed II: The Album     Mike WiLL Made-It   602577321153
# 7   Based On A T.R.U. Story (Deluxe)              2 Chainz   602537127603
# 8                              Jaime       Brittany Howard   880882359355
# 9                            Evasion                CloZee  3760209412406
# 10       No.6 Collaborations Project            Ed Sheeran   190295384234
# 11              EMW II - The Ñuulest                   Nix   859728500589
# ...

# %% [markdown]
# Accedemos a la primer columna para mostrar la informacion.
# En nuestro archivo de excel, tenemos una pestaña llamada: title, nuestro dataframe tiene la informacion de esa pestaña. Todas las filas y columns. Notemos que la primer columna se llama: title y la segunda artist. `Entonces, la pestaña y la primer column tienen el mismo nombre, no confundir.`

# %%
df_read['title']
# Out:
# 0                              Letters
# 1                Three Dimensions Deep
# 2                           Born Again
# 3                               HNDRXX
# 4                    All Rise (Deluxe)
# 5                          After Hours
# 6                  Creed II: The Album
# 7     Based On A T.R.U. Story (Deluxe)
# 8                                Jaime
# 9                              Evasion
# 10         No.6 Collaborations Project
# 11                EMW II - The Ñuulest
# 12                         Nan Fon Bwa
# 13              Another Summer of Love
# 14          Big Part Of A Big Sun - EP
# 15                        Another Side
# 16                   French Kiwi Juice
# 17                   Mountains of Gold
# 18                          Droptopwop
# Name: title, dtype: object

# %% [markdown]
# Podemos unicamente mostrar las columnas que necesitemos

# %%
df_read[['title', 'artist']]
# Out:
#                                title                artist
# 0                            Letters          Chris Daniel
# 1              Three Dimensions Deep            Amber Mark
# 2                         Born Again  The Notorious B.I.G.
# 3                             HNDRXX                Future
# 4                  All Rise (Deluxe)        Gregory Porter
# 5                        After Hours            The Weeknd
# 6                Creed II: The Album     Mike WiLL Made-It
# 7   Based On A T.R.U. Story (Deluxe)              2 Chainz
# 8                              Jaime       Brittany Howard
# 9                            Evasion                CloZee
# 10       No.6 Collaborations Project            Ed Sheeran
# 11              EMW II - The Ñuulest                   Nix
# 12                       Nan Fon Bwa       Melissa Laveaux
# 13            Another Summer of Love           GospelbeacH
# 14        Big Part Of A Big Sun - EP           DeLaurentis
# ...
